# %%
from qiskit_machine_learning.kernels import QuantumKernel
from qiskit_machine_learning.algorithms import QSVC
from qiskit.circuit.library import ZZFeatureMap
from qiskit import Aer

# ----- Example Data -----
X_train = [[0.1, 0.5], [0.2, 0.3], [0.8, 0.4], [0.7, 0.2]]
y_train = [0, 0, 1, 1]

# ----- Feature Map -----
feature_map = ZZFeatureMap(feature_dimension=2, reps=2)

# ----- Aer backend -----
backend = Aer.get_backend("statevector_simulator")

# ----- Quantum Kernel -----
kernel = QuantumKernel(feature_map=feature_map, quantum_instance=backend)

# ----- Quantum Support Vector Classifier -----
model = QSVC(quantum_kernel=kernel)
model.fit(X_train, y_train)

# ----- Prediction -----
print("Prediction:", model.predict([[0.6, 0.3]]))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17260\3686115384.py:14: DeprecationWarning: The 'qiskit.Aer' entry point is deprecated and will be removed in Qiskit 1.0. You should use 'qiskit_aer.Aer' directly instead.
#   backend = Aer.get_backend("statevector_simulator")
# C:\Users\Dell\anaconda3\envs\qiskit_ml\lib\site-packages\qiskit\providers\ibmq\api\session.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Prediction: [1]
